# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
fin = pd.read_excel('financial.xlsx',index_col=0)
fin
# Out:
#                              shortName                        industry  \
# Sr.NO
# 0                           Apple Inc.            Consumer Electronics
# 1                Microsoft Corporation         Software—Infrastructure
# 2                        Alphabet Inc.  Internet Content & Information
# 3                        Alphabet Inc.  Internet Content & Information
# 4                     Amazon.com, Inc.                 Internet Retail
# ...                                ...                             ...
# 236    Public Service Enterprise Group           Utilities—Diversified
# 237          T. Rowe Price Group, Inc.                Asset Management
# 238                Halliburton Company  Oil & Gas Equipment & Services
# 239                          eBay Inc.                 Internet Retail
# 240             Verisk Analytics, Inc.             Consulting Services
#
#        revenueGrowth  operatingMargins        ebitda  currentRatio  \
# Sr.NO
# 0              0.112           0.30900  128217997312         1.038
# 1              0.201           0.42524   90829996032         2.247
# 2              0.324           0.30552   91144003584         2.928
# 3              0.324           0.30552   91144003584         2.928
# 4              0.094           0.05295   59174998016         1.136
# ...              ...               ...           ...           ...
# 236           -0.197           0.17766    3068999936         0.841
# 237            0.132           0.48774    3946700032         1.569
# 238            0.297           0.10193    2355000064         2.390
# 239            0.108           0.25193    3475000064         3.353
# 240            0.080           0.35978    1319500032         0.507
#
#        returnOnAssets  debtToEquity  returnOnEquity     marketCap
# Sr.NO
# 0             0.19875       170.714         1.45567  2.851326e+12
# 1             0.15249        50.217         0.49051  2.276649e+12
# 2             0.14493        11.329         0.32069  1.872632e+12
# 3             0.14493        11.329         0.32069  1.871194e+12
# 4             0.04193       100.864         0.28806  1.676880e+12
# ...               ...           ...             ...           ...
# 236           0.02034       141.986        -0.04427  3.454191e+10
# 237           0.20189         3.537         0.31743  3.413217e+10
# 238           0.04335       180.941         0.07599  3.482001e+10
# 239           0.07703        85.034         0.28446  3.594515e+10
# 240           0.08902       124.735         0.27185  3.352149e+10
#
# [226 rows x 10 columns]

# %%
fin.head()
# Out:
#                    shortName                        industry  revenueGrowth  \
# Sr.NO
# 0                 Apple Inc.            Consumer Electronics          0.112
# 1      Microsoft Corporation         Software—Infrastructure          0.201
# 2              Alphabet Inc.  Internet Content & Information          0.324
# 3              Alphabet Inc.  Internet Content & Information          0.324
# 4           Amazon.com, Inc.                 Internet Retail          0.094
#
#        operatingMargins        ebitda  currentRatio  returnOnAssets  \
# Sr.NO
# 0               0.30900  128217997312         1.038         0.19875
# 1               0.42524   90829996032         2.247         0.15249
# 2               0.30552   91144003584         2.928         0.14493
# 3               0.30552   91144003584         2.928         0.14493
# 4               0.05295   59174998016         1.136         0.04193
#
#        debtToEquity  returnOnEquity     marketCap
# Sr.NO
# 0           170.714         1.45567  2.851326e+12
# 1            50.217         0.49051  2.276649e+12
# 2            11.329         0.32069  1.872632e+12
# 3            11.329         0.32069  1.871194e+12
# 4           100.864         0.28806  1.676880e+12

# %%
fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, 0 to 240
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   shortName         226 non-null    object
#  1   industry          226 non-null    object
#  2   revenueGrowth     226 non-null    float64
#  3   operatingMargins  226 non-null    float64
#  4   ebitda            226 non-null    int64
#  5   currentRatio      223 non-null    float64
#  6   returnOnAssets    223 non-null    float64
#  7   debtToEquity      209 non-null    float64
#  8   returnOnEquity    213 non-null    float64
#  9   marketCap         224 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 19.4+ KB

# %%
fin.describe()
# Out:
#        revenueGrowth  operatingMargins        ebitda  currentRatio  \
# count     226.000000        226.000000  2.260000e+02    223.000000
# mean        0.356938          0.227639  1.002093e+10      1.570238
# std         2.048120          0.133183  1.556694e+10      1.036124
# min        -0.197000         -0.008110  4.471000e+08      0.286000
# 25%         0.078500          0.140363  2.999175e+09      0.956000
# 50%         0.132000          0.209065  5.385000e+09      1.302000
# 75%         0.242500          0.308623  1.028200e+10      1.780500
# max        30.650000          0.664520  1.282180e+11      7.145000
#
#        returnOnAssets  debtToEquity  returnOnEquity     marketCap
# count      223.000000    209.000000      213.000000  2.240000e+02
# mean         0.079557    151.334282        0.518815  1.527259e+11
# std          0.058375    356.248589        1.473005  3.238562e+11
# min         -0.002170      0.318000       -0.044270  3.352149e+10
# 25%          0.035535     43.902000        0.110480  4.373719e+10
# 50%          0.067900     78.371000        0.214710  6.614670e+10
# 75%          0.108095    145.940000        0.393870  1.349175e+11
# max          0.372000   4373.430000       14.017540  2.851326e+12

# %%
fin.isnull().sum()
# Out:
# shortName            0
# industry             0
# revenueGrowth        0
# operatingMargins     0
# ebitda               0
# currentRatio         3
# returnOnAssets       3
# debtToEquity        17
# returnOnEquity      13
# marketCap            2
# dtype: int64

# %%
df = fin.dropna()

# %%
df.shape
# Out:
# (205, 10)

# %%
plt.hist(df['returnOnAssets'])
# Out:
# (array([67., 56., 40., 20.,  9.,  9.,  2.,  1.,  0.,  1.]),
#  array([0.00451 , 0.041259, 0.078008, 0.114757, 0.151506, 0.188255,
#         0.225004, 0.261753, 0.298502, 0.335251, 0.372   ]),
#  <BarContainer object of 10 artists>)

# %%
x = df[['currentRatio']]
y = df[['returnOnAssets']]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(x,y)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# array([0.03940605])

# %%
regression.coef_
# Out:
# array([[0.02351008]])

# %%
from sklearn.metrics import r2_score

# %%
y_pred = regression.predict(x)
y_pred
# Out:
# array([[0.06380952],
#        [0.09223321],
#        [0.10824358],
#        [0.10824358],
#        [0.06611351],
#        [0.07196752],
#        [0.2073856 ],
#        [0.11355686],
#        [0.05633331],
#        [0.07109765],
#        [0.06122341],
#        [0.05520483],
#        [0.06395058],
#        [0.06968704],
#        [0.06601947],
#        [0.07196752],
#        [0.07001618],
#        [0.07504734],
#        [0.10149618],
#        [0.06486747],
#        [0.06326879],
#        [0.06162308],
#        [0.07744537],
#        [0.07476522],
#        [0.06815889],
#        [0.06230488],
#        [0.06435025],
#        [0.0635274 ],
#        [0.08882425],
#        [0.08233547],
#        [0.11153499],
#        [0.07304898],
#        [0.06874664],
#        [0.07018075],
#        [0.07410694],
#        [0.07815067],
#        [0.05393529],
#        [0.16464427],
#        [0.05588662],
#        [0.06691285],
#        [0.05040877],
#        [0.05692107],
#        [0.07516489],
#        [0.06030652],
#        [0.06832346],
#        [0.08699046],
#        [0.10789093],
#        [0.06150553],
#        [0.09369084],
#        [0.07079202],
#        [0.06992214],
#        [0.06968704],
#        [0.07803312],
#        [0.09094016],
#        [0.08875372],
#        [0.09909816],
#        [0.07410694],
#        [0.07269633],
#        [0.07363674],
#        [0.05906048],
#        [0.06599596],
#        [0.0593426 ],
#        [0.07295494],
#        [0.05757935],
#        [0.04612994],
#        [0.08163016],
#        [0.15890781],
#        [0.0621403 ],
#        [0.08132453],
#        [0.08938849],
#        [0.09778159],
#        [0.06388005],
#        [0.0474465 ],
#        [0.13006093],
#        [0.06310422],
#        [0.11231082],
#        [0.08503913],
#        [0.05663895],
#        [0.07949075],
#        [0.05367667],
#        [0.06860558],
#        [0.07979638],
#        [0.07177944],
#        [0.11626052],
#        [0.05586311],
#        [0.0630572 ],
#        [0.0539588 ],
#        [0.07076851],
#        [0.09858093],
#        [0.07152083],
#        [0.05870783],
#        [0.07109765],
#        [0.12319599],
#        [0.06966353],
#        [0.06594894],
#        [0.0700632 ],
#        [0.08898882],
#        [0.06456184],
#        [0.11184062],
#        [0.07302547],
#        [0.04739948],
#        [0.05593364],
#        [0.06764166],
#        [0.09101069],
#        [0.08818948],
#        [0.06406813],
#        [0.05891942],
#        [0.07768047],
#        [0.06533768],
#        [0.05764988],
#        [0.14814019],
#        [0.17014563],
#        [0.10217798],
#        [0.06491449],
#        [0.06388005],
#        [0.07582317],
#        [0.07521191],
#        [0.07504734],
#        [0.06813538],
#        [0.05680352],
#        [0.07453012],
#        [0.07114467],
#        [0.06218732],
#        [0.05109057],
#        [0.07979638],
#        [0.09665311],
#        [0.08179473],
#        [0.06491449],
#        [0.1024601 ],
#        [0.10974822],
#        [0.05687405],
#        [0.07648146],
#        [0.04775213],
#        [0.06472641],
#        [0.07991393],
#        [0.0716854 ],
#        [0.06745358],
#        [0.07551754],
#        [0.06540821],
#        [0.05764988],
#        [0.05306541],
#        [0.08830703],
#        [0.06597245],
#        [0.07688113],
#        [0.05842571],
#        [0.06524364],
#        [0.06926386],
#        [0.06884068],
#        [0.15636872],
#        [0.09665311],
#        [0.07939671],
#        [0.06914631],
#        [0.04789319],
#        [0.06058864],
#        [0.0765755 ],
#        [0.06150553],
#        [0.08186526],
#        [0.07925564],
#        [0.15846111],
#        [0.06138798],
#        [0.04866903],
#        [0.06806485],
#        [0.08200632],
#        [0.0747182 ],
#        [0.07923213],
#        [0.05548695],
#        [0.07055691],
#        [0.05814359],
#        [0.14995046],
#        [0.0502442 ],
#        [0.09881603],
#        [0.05605119],
#        [0.09169248],
#        [0.06775921],
#        [0.05894293],
#        [0.05880187],
#        [0.05313594],
#        [0.05929558],
#        [0.07683411],
#        [0.04946837],
#        [0.06893472],
#        [0.07986691],
#        [0.08673185],
#        [0.09519548],
#        [0.05424092],
#        [0.04965645],
#        [0.0576969 ],
#        [0.06646616],
#        [0.07476522],
#        [0.10948961],
#        [0.0775159 ],
#        [0.06639563],
#        [0.07032181],
#        [0.06884068],
#        [0.09914518],
#        [0.07913809],
#        [0.06992214],
#        [0.11508501],
#        [0.06987512],
#        [0.06397409],
#        [0.05917803],
#        [0.07629337],
#        [0.09559515],
#        [0.11823536],
#        [0.05132567]])

# %%
R_square = r2_score(y,y_pred)
R_square
# Out:
# 0.18102632739500424

# %%
plt.scatter(x,y)
plt.plot(x,y_pred,color='red')

# %%
import statsmodels.api as sm

# %%
x1=sm.add_constant(x)

# %%
mol=sm.OLS(y,x1).fit()

# %%
print(mol.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         returnOnAssets   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     44.87
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):           2.03e-10
# Time:                        19:30:49   Log-Likelihood:                 315.74
# No. Observations:                 205   AIC:                            -627.5
# Df Residuals:                     203   BIC:                            -620.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0394      0.007      5.915      0.000       0.026       0.053
# currentRatio     0.0235      0.004      6.699      0.000       0.017       0.030
# ==============================================================================
# Omnibus:                       86.711   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              346.107
# Skew:                           1.674   Prob(JB):                     6.98e-76
# Kurtosis:                       8.413   Cond. No.                         4.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = df[['currentRatio']]
y = df['returnOnAssets']

# %%
X=sm.add_constant(x)
X
# Out:
#        const  currentRatio
# Sr.NO
# 0        1.0         1.038
# 1        1.0         2.247
# 2        1.0         2.928
# 3        1.0         2.928
# 4        1.0         1.136
# ...      ...           ...
# 236      1.0         0.841
# 237      1.0         1.569
# 238      1.0         2.390
# 239      1.0         3.353
# 240      1.0         0.507
#
# [205 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y)

# %%
X_train.shape
# Out:
# (153, 2)

# %%
X_test.shape
# Out:
# (52, 2)
